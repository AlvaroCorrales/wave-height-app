# %% [markdown]
# # Processing data for wave height forecast
# In this notebook, we process the data that we use to train and fine tune our models.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import os
from collections import defaultdict

plt.style.use('seaborn-v0_8-darkgrid')

# %% [markdown]
# ## 1. Wave data

# %%
# Read raw data
# ==============================================================================
# Directory containing the CSV files
directory = '../../Data/queensland/raw'

# List all CSV files in the directory
csv_files = [f for f in os.listdir(directory) if f.endswith('.csv')]

# Dictionary to map possible column names to standard names
column_mapping = {
    'Date/Time': 'datetime',
    'Date/Time (AEST)': 'datetime',
    'Peak Direction': 'wave_direction',
    'Peak Direction (degrees)': 'wave_direction',
    'Tz': 'wave_period',
    'Tz (s)': 'wave_period',
    'Hmax': 'wave_height',
    'Hmax (m)': 'wave_height'
}

# Dictionary to hold lists of file names grouped by site
site_files = defaultdict(list)

# Group files by site
for file_name in csv_files:
    # Extract the site name (part before the first underscore)
    site_name = file_name.split('_')[0]
    # Add the file to the corresponding site group
    site_files[site_name].append(file_name)

# List to hold the final DataFrames, one per site
df_list = []

# Process each site group
for site, files in site_files.items():
    site_dfs = []
    
    for file in files:
        file_path = os.path.join(directory, file)
        # Read the CSV file
        df = pd.read_csv(file_path)
        
        # Rename columns to a consistent format using the mapping dictionary
        df = df.rename(columns=column_mapping)
        
        # Select only the standardized columns we care about
        df = df[['datetime', 'wave_direction', 'wave_period', 'wave_height']]

        # Set right format for datetime variable
        df['datetime'] = pd.to_datetime(df['datetime'])
        df['datetime'] = df['datetime'].dt.strftime('%Y-%m-%d %H:%M:%S')
        
        # Append the processed DataFrame to the list for this site
        site_dfs.append(df)
    
    # Concatenate all DataFrames for this site
    site_df = pd.concat(site_dfs, ignore_index=True)
    
    # Sort by the datetime column
    site_df = site_df.sort_values('datetime')
    site_df.set_index(keys = 'datetime', inplace=True)
    # site_df = df.asfreq('30min')

    # Keep site name in df
    site_df['site'] = site
    
    # Append the concatenated and sorted DataFrame to the list
    df_list.append(site_df)

# df_list now contains one DataFrame per site, each sorted by datetime

# %%
df_list[0]
# Out:
#                      wave_direction  wave_period  wave_height     site
# datetime
# 2021-06-01 00:00:00           78.51      -99.900      -99.900  bilinga
# 2021-06-01 00:30:00           77.89      -99.900      -99.900  bilinga
# 2021-06-01 01:00:00           79.12      -99.900      -99.900  bilinga
# 2021-06-01 01:30:00           78.86      -99.900      -99.900  bilinga
# 2021-06-01 02:00:00           78.51      -99.900      -99.900  bilinga
# ...                             ...          ...          ...      ...
# 2023-12-31 21:30:00           67.60        3.611        1.826  bilinga
# 2023-12-31 22:00:00           74.99        3.559        1.933  bilinga
# 2023-12-31 22:30:00           66.11        3.838        2.096  bilinga
# 2023-12-31 23:00:00           67.60        3.779        2.016  bilinga
# 2023-12-31 23:30:00            0.00        3.978        1.761  bilinga
#
# [45312 rows x 4 columns]

# %%
# Create dataframes separating wave height, period and direction
df_list_height = []
df_list_period = []
df_list_direction = []

for _df in df_list:
    
    # Height
    _df_h = _df[['wave_height', 'site']].copy()
    df_list_height.append(_df_h)

    # Period
    _df_p = _df[['wave_period', 'site']].copy() 
    df_list_period.append(_df_p)    

    # Direction
    _df_d = _df[['wave_direction', 'site']].copy() 
    df_list_direction.append(_df_d)

# %%
# Create one single dataframe for wave heights
# Initialize an empty DataFrame for the merge operation
df_height = pd.DataFrame()

# Iterate over each DataFrame in the list
for df in df_list_height:
    # Extract the site name from the first observation of the 'site' column
    site_name = df['site'].iloc[0]
    
    # Rename the 'wave_height' column to include the site name
    df_renamed = df[['wave_height']].rename(columns={'wave_height': f'wave_height_{site_name}'})
    
    # Merge with the existing merged_df on the 'datetime' index
    if df_height.empty:
        # If merged_df is empty, initialize it with the first DataFrame
        df_height = df_renamed
    else:
        df_height = df_height.merge(df_renamed, left_index=True, right_index=True, how='outer')

# Create one single dataframe for wave direction
# Initialize an empty DataFrame for the merge operation
df_direction = pd.DataFrame()

# Iterate over each DataFrame in the list
for df in df_list_direction:
    # Extract the site name from the first observation of the 'site' column
    site_name = df['site'].iloc[0]
    
    # Rename the 'wave_height' column to include the site name
    df_renamed = df[['wave_direction']].rename(columns={'wave_direction': f'wave_direction_{site_name}'})
    
    # Merge with the existing merged_df on the 'datetime' index
    if df_direction.empty:
        # If merged_df is empty, initialize it with the first DataFrame
        df_direction = df_renamed
    else:
        df_direction = df_direction.merge(df_renamed, left_index=True, right_index=True, how='outer')

# Create one single dataframe for wave period
# Initialize an empty DataFrame for the merge operation
df_period = pd.DataFrame()

# Iterate over each DataFrame in the list
for df in df_list_period:
    # Extract the site name from the first observation of the 'site' column
    site_name = df['site'].iloc[0]
    
    # Rename the 'wave_height' column to include the site name
    df_renamed = df[['wave_period']].rename(columns={'wave_period': f'wave_period_{site_name}'})
    
    # Merge with the existing merged_df on the 'datetime' index
    if df_period.empty:
        # If merged_df is empty, initialize it with the first DataFrame
        df_period = df_renamed
    else:
        df_period = df_period.merge(df_renamed, left_index=True, right_index=True, how='outer')

# %%
df_direction
# Out:
#                      wave_direction_bilinga  wave_direction_tweed-heads-mk4  \
# datetime
# 2021-01-01 00:00:00                     NaN                           92.48
# 2021-01-01 00:30:00                     NaN                           77.80
# 2021-01-01 01:00:00                     NaN                           78.07
# 2021-01-01 01:30:00                     NaN                           83.60
# 2021-01-01 02:00:00                     NaN                           77.27
# ...                                     ...                             ...
# 2024-07-31 21:30:00                     NaN                             NaN
# 2024-07-31 22:00:00                     NaN                             NaN
# 2024-07-31 22:30:00                     NaN                             NaN
# 2024-07-31 23:00:00                     NaN                             NaN
# 2024-07-31 23:30:00                     NaN                             NaN
#
#                      wave_direction_palm-beach-mk4  \
# datetime
# 2021-01-01 00:00:00                          87.74
# 2021-01-01 00:30:00                          70.24
# 2021-01-01 01:00:00                          72.70
# 2021-01-01 01:30:00                          72.79
# 2021-01-01 02:00:00                          78.51
# ...                                            ...
# 2024-07-31 21:30:00                            NaN
# 2024-07-31 22:00:00                            NaN
# 2024-07-31 22:30:00                            NaN
# 2024-07-31 23:00:00                            NaN
# 2024-07-31 23:30:00                            NaN
#
#                      wave_direction_caloundra-pob  \
# datetime
# 2021-01-01 00:00:00                          85.0
# 2021-01-01 00:30:00                          91.0
# 2021-01-01 01:00:00                          75.0
# 2021-01-01 01:30:00                          75.0
# 2021-01-01 02:00:00                          74.0
# ...                                           ...
# 2024-07-31 21:30:00                           NaN
# 2024-07-31 22:00:00                           NaN
# 2024-07-31 22:30:00                           NaN
# 2024-07-31 23:00:00                           NaN
# 2024-07-31 23:30:00                           NaN
#
#                      wave_direction_gladstone-gpa  \
# datetime
# 2021-01-01 00:00:00                        -99.90
# 2021-01-01 00:30:00                        -99.90
# 2021-01-01 01:00:00                         79.62
# 2021-01-01 01:30:00                         73.62
# 2021-01-01 02:00:00                         86.62
# ...                                           ...
# 2024-07-31 21:30:00                           NaN
# 2024-07-31 22:00:00                           NaN
# 2024-07-31 22:30:00                           NaN
# 2024-07-31 23:00:00                           NaN
# 2024-07-31 23:30:00                           NaN
#
#                      wave_direction_brisbane-mk4  wave_direction_bundaberg  \
# datetime
# 2021-01-01 00:00:00                       129.05                    -99.90
# 2021-01-01 00:30:00                       134.15                    -99.90
# 2021-01-01 01:00:00                       127.56                     10.09
# 2021-01-01 01:30:00                       125.54                     10.09
# 2021-01-01 02:00:00                       135.65                     10.09
# ...                                          ...                       ...
# 2024-07-31 21:30:00                       137.68                       NaN
# 2024-07-31 22:00:00                       130.03                       NaN
# 2024-07-31 22:30:00                       134.42                       NaN
# 2024-07-31 23:00:00                       131.00                       NaN
# 2024-07-31 23:30:00                         0.00                       NaN
#
#                      wave_direction_townsville  wave_direction_mooloolaba  \
# datetime
# 2021-01-01 00:00:00                     -99.90                       63.0
# 2021-01-01 00:30:00                     -99.90                       73.0
# 2021-01-01 01:00:00                      95.43                       61.0
# 2021-01-01 01:30:00                      90.43                       73.0
# 2021-01-01 02:00:00                      87.43                       70.0
# ...                                        ...                        ...
# 2024-07-31 21:30:00                        NaN                        NaN
# 2024-07-31 22:00:00                        NaN                        NaN
# 2024-07-31 22:30:00                        NaN                        NaN
# 2024-07-31 23:00:00                        NaN                        NaN
# 2024-07-31 23:30:00                        NaN                        NaN
#
#                      wave_direction_cairns  wave_direction_mackay-mk4
# datetime
# 2021-01-01 00:00:00                 -99.90                     119.65
# 2021-01-01 00:30:00                 -99.90                     119.21
# 2021-01-01 01:00:00                 145.61                     122.73
# 2021-01-01 01:30:00                 136.61                     119.47
# 2021-01-01 02:00:00                 118.61                     118.15
# ...                                    ...                        ...
# 2024-07-31 21:30:00                    NaN                        NaN
# 2024-07-31 22:00:00                    NaN                        NaN
# 2024-07-31 22:30:00                    NaN                        NaN
# 2024-07-31 23:00:00                    NaN                        NaN
# 2024-07-31 23:30:00                    NaN                        NaN
#
# [62784 rows x 11 columns]

# %%
df_direction['wave_direction_bilinga'].isna().value_counts()
# Out:
# wave_direction_bilinga
# False    45312
# True     17472
# Name: count, dtype: int64

# %% [markdown]
# ### Dealing with null values.

# %% [markdown]
# Null value is -99.900. We transform -99.9 into NaN, as it can be processed by XGBoost.

# %%
for df in [df_direction, df_height, df_period]:
    for col in df.columns:
        df[col].replace(-99.90, np.nan, inplace=True)
        df[col].replace(0.00, np.nan, inplace = True)

# %%
df_direction.tail()
# Out:
#                      wave_direction_bilinga  wave_direction_tweed-heads-mk4  \
# datetime
# 2024-07-31 21:30:00                     NaN                             NaN
# 2024-07-31 22:00:00                     NaN                             NaN
# 2024-07-31 22:30:00                     NaN                             NaN
# 2024-07-31 23:00:00                     NaN                             NaN
# 2024-07-31 23:30:00                     NaN                             NaN
#
#                      wave_direction_palm-beach-mk4  \
# datetime
# 2024-07-31 21:30:00                            NaN
# 2024-07-31 22:00:00                            NaN
# 2024-07-31 22:30:00                            NaN
# 2024-07-31 23:00:00                            NaN
# 2024-07-31 23:30:00                            NaN
#
#                      wave_direction_caloundra-pob  \
# datetime
# 2024-07-31 21:30:00                           NaN
# 2024-07-31 22:00:00                           NaN
# 2024-07-31 22:30:00                           NaN
# 2024-07-31 23:00:00                           NaN
# 2024-07-31 23:30:00                           NaN
#
#                      wave_direction_gladstone-gpa  \
# datetime
# 2024-07-31 21:30:00                           NaN
# 2024-07-31 22:00:00                           NaN
# 2024-07-31 22:30:00                           NaN
# 2024-07-31 23:00:00                           NaN
# 2024-07-31 23:30:00                           NaN
#
#                      wave_direction_brisbane-mk4  wave_direction_bundaberg  \
# datetime
# 2024-07-31 21:30:00                       137.68                       NaN
# 2024-07-31 22:00:00                       130.03                       NaN
# 2024-07-31 22:30:00                       134.42                       NaN
# 2024-07-31 23:00:00                       131.00                       NaN
# 2024-07-31 23:30:00                          NaN                       NaN
#
#                      wave_direction_townsville  wave_direction_mooloolaba  \
# datetime
# 2024-07-31 21:30:00                        NaN                        NaN
# 2024-07-31 22:00:00                        NaN                        NaN
# 2024-07-31 22:30:00                        NaN                        NaN
# 2024-07-31 23:00:00                        NaN                        NaN
# 2024-07-31 23:30:00                        NaN                        NaN
#
#                      wave_direction_cairns  wave_direction_mackay-mk4
# datetime
# 2024-07-31 21:30:00                    NaN                        NaN
# 2024-07-31 22:00:00                    NaN                        NaN
# 2024-07-31 22:30:00                    NaN                        NaN
# 2024-07-31 23:00:00                    NaN                        NaN
# 2024-07-31 23:30:00                    NaN                        NaN

# %% [markdown]
# ### Drop 2024, as we don't have it for most sites

# %%
cutoff_date = pd.Timestamp('2023-12-31 23:30:00')

df_direction.index = pd.to_datetime(df_direction.index)
df_direction = df_direction[df_direction.index <= cutoff_date]

df_height.index = pd.to_datetime(df_height.index)
df_height = df_height[df_height.index <= cutoff_date]

df_period.index = pd.to_datetime(df_period.index)
df_period = df_period[df_period.index <= cutoff_date]

# %%
df_period
# Out:
#                      wave_period_bilinga  wave_period_tweed-heads-mk4  \
# datetime
# 2021-01-01 00:00:00                  NaN                        4.941
# 2021-01-01 00:30:00                  NaN                        4.952
# 2021-01-01 01:00:00                  NaN                        4.756
# 2021-01-01 01:30:00                  NaN                        5.022
# 2021-01-01 02:00:00                  NaN                        4.785
# ...                                  ...                          ...
# 2023-12-31 21:30:00                3.611                        4.369
# 2023-12-31 22:00:00                3.559                        4.341
# 2023-12-31 22:30:00                3.838                        4.425
# 2023-12-31 23:00:00                3.779                        4.769
# 2023-12-31 23:30:00                3.978                        4.781
#
#                      wave_period_palm-beach-mk4  wave_period_caloundra-pob  \
# datetime
# 2021-01-01 00:00:00                       4.582                      4.560
# 2021-01-01 00:30:00                       4.522                      4.431
# 2021-01-01 01:00:00                       4.555                      4.588
# 2021-01-01 01:30:00                       4.550                      4.881
# 2021-01-01 02:00:00                       4.386                      4.669
# ...                                         ...                        ...
# 2023-12-31 21:30:00                       3.843                        NaN
# 2023-12-31 22:00:00                       4.000                        NaN
# 2023-12-31 22:30:00                       4.139                        NaN
# 2023-12-31 23:00:00                       4.199                        NaN
# 2023-12-31 23:30:00                       4.406                        NaN
#
#                      wave_period_gladstone-gpa  wave_period_brisbane-mk4  \
# datetime
# 2021-01-01 00:00:00                        NaN                       NaN
# 2021-01-01 00:30:00                      4.163                       NaN
# 2021-01-01 01:00:00                      4.101                     5.090
# 2021-01-01 01:30:00                      4.327                       NaN
# 2021-01-01 02:00:00                      4.458                       NaN
# ...                                        ...                       ...
# 2023-12-31 21:30:00                      3.493                     4.018
# 2023-12-31 22:00:00                      3.373                     4.320
# 2023-12-31 22:30:00                      3.526                     4.409
# 2023-12-31 23:00:00                      3.539                     4.717
# 2023-12-31 23:30:00                      3.624                     4.501
#
#                      wave_period_bundaberg  wave_period_townsville  \
# datetime
# 2021-01-01 00:00:00                    NaN                     NaN
# 2021-01-01 00:30:00                  3.865                   3.468
# 2021-01-01 01:00:00                  3.809                   3.398
# 2021-01-01 01:30:00                  3.902                   3.424
# 2021-01-01 02:00:00                  3.858                   3.328
# ...                                    ...                     ...
# 2023-12-31 21:30:00                    NaN                   3.418
# 2023-12-31 22:00:00                    NaN                   3.345
# 2023-12-31 22:30:00                    NaN                   3.325
# 2023-12-31 23:00:00                    NaN                   3.274
# 2023-12-31 23:30:00                    NaN                   3.089
#
#                      wave_period_mooloolaba  wave_period_cairns  \
# datetime
# 2021-01-01 00:00:00                   4.988                 NaN
# 2021-01-01 00:30:00                   5.066               2.502
# 2021-01-01 01:00:00                   5.031               2.488
# 2021-01-01 01:30:00                   5.104               2.630
# 2021-01-01 02:00:00                   5.083               2.531
# ...                                     ...                 ...
# 2023-12-31 21:30:00                   4.023                 NaN
# 2023-12-31 22:00:00                   4.205                 NaN
# 2023-12-31 22:30:00                   4.383                 NaN
# 2023-12-31 23:00:00                   4.261                 NaN
# 2023-12-31 23:30:00                   4.415                 NaN
#
#                      wave_period_mackay-mk4
# datetime
# 2021-01-01 00:00:00                   4.185
# 2021-01-01 00:30:00                   4.208
# 2021-01-01 01:00:00                   4.131
# 2021-01-01 01:30:00                   4.135
# 2021-01-01 02:00:00                   4.103
# ...                                     ...
# 2023-12-31 21:30:00                   3.250
# 2023-12-31 22:00:00                     NaN
# 2023-12-31 22:30:00                   3.632
# 2023-12-31 23:00:00                     NaN
# 2023-12-31 23:30:00                     NaN
#
# [52560 rows x 11 columns]

# %% [markdown]
# ## Save

# %%
dir = '../../Data/queensland/processed/'
df_direction.to_csv(dir + 'qld_direction.csv')
df_height.to_csv(dir + 'qld_height.csv')
df_period.to_csv(dir + 'qld_period.csv')
